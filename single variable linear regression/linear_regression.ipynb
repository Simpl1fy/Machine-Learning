# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
data = pd.read_csv('tvmarketing.csv')
data.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
X = data.iloc[:, 0]
y = data.iloc[:, 1]

# %%
X.head()
# Out:
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# Name: TV, dtype: float64

# %%
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: Sales, dtype: float64

# %%
plt.scatter(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.3)

# %%
X_train
# Out:
# 131    265.2
# 96     197.6
# 181    218.5
# 19     147.3
# 153    171.3
#        ...
# 67     139.3
# 192     17.2
# 117     76.4
# 47     239.9
# 172     19.6
# Name: TV, Length: 140, dtype: float64

# %%
X_train = np.array(X_train).reshape(-1, 1)
print(X_train)
# Out:
# [[265.2]
#  [197.6]
#  [218.5]
#  [147.3]
#  [171.3]
#  [217.7]
#  [262.7]
#  [163.5]
#  [100.4]
#  [ 76.3]
#  [184.9]
#  [134.3]
#  [273.7]
#  [296.4]
#  [ 96.2]
#  [109.8]
#  [255.4]
#  [204.1]
#  [240.1]
#  [193.7]
#  [191.1]
#  [ 89.7]
#  [ 43. ]
#  [ 38.2]
#  [ 13.1]
#  [239.3]
#  [ 17.2]
#  [210.7]
#  [ 25.6]
#  [177. ]
#  [206.9]
#  [ 66.1]
#  [149.7]
#  [129.4]
#  [ 94.2]
#  [276.7]
#  [276.9]
#  [  7.8]
#  [250.9]
#  [175.7]
#  [ 11.7]
#  [ 75.5]
#  [199.8]
#  [230.1]
#  [107.4]
#  [225.8]
#  [163.3]
#  [131.1]
#  [206.8]
#  [177. ]
#  [216.8]
#  [ 66.9]
#  [227.2]
#  [193.2]
#  [ 97.5]
#  [ 85.7]
#  [228.3]
#  [139.5]
#  [ 48.3]
#  [218.4]
#  [195.4]
#  [  5.4]
#  [238.2]
#  [216.4]
#  [222.4]
#  [ 27.5]
#  [151.5]
#  [139.2]
#  [117.2]
#  [283.6]
#  [ 57.5]
#  [237.4]
#  [213.5]
#  [ 18.8]
#  [  4.1]
#  [164.5]
#  [ 93.9]
#  [ 28.6]
#  [232.1]
#  [214.7]
#  [ 19.4]
#  [280.2]
#  [290.7]
#  [136.2]
#  [ 69. ]
#  [ 44.5]
#  [141.3]
#  [188.4]
#  [293.6]
#  [137.9]
#  [  8.4]
#  [168.4]
#  [281.4]
#  [ 43.1]
#  [219.8]
#  [182.6]
#  [149.8]
#  [220.3]
#  [ 95.7]
#  [248.8]
#  [ 78.2]
#  [121. ]
#  [112.9]
#  [ 17.9]
#  [ 80.2]
#  [248.4]
#  [ 97.2]
#  [220.5]
#  [284.3]
#  [243.2]
#  [ 70.6]
#  [135.2]
#  [ 75.3]
#  [116. ]
#  [ 75.1]
#  [ 38. ]
#  [166.8]
#  [ 26.8]
#  [120.5]
#  [262.9]
#  [234.5]
#  [239.8]
#  [286. ]
#  [222.4]
#  [ 39.5]
#  [228. ]
#  [210.8]
#  [ 73.4]
#  [ 88.3]
#  [199.1]
#  [110.7]
#  [266.9]
#  [237.4]
#  [199.8]
#  [187.9]
#  [139.3]
#  [ 17.2]
#  [ 76.4]
#  [239.9]
#  [ 19.6]]

# %%
X_test = np.array(X_test).reshape(-1, 1)
X_test
# Out:
# array([[ 69.2],
#        [ 50. ],
#        [ 90.4],
#        [289.7],
#        [170.2],
#        [ 56.2],
#        [  8.7],
#        [240.1],
#        [ 23.8],
#        [197.6],
#        [261.3],
#        [ 87.2],
#        [156.6],
#        [187.8],
#        [ 76.4],
#        [120.2],
#        [265.6],
#        [  0.7],
#        [ 74.7],
#        [213.4],
#        [287.6],
#        [140.3],
#        [175.1],
#        [131.7],
#        [ 53.5],
#        [123.1],
#        [165.6],
#        [205. ],
#        [224. ],
#        [ 25.1],
#        [ 67.8],
#        [198.9],
#        [280.7],
#        [241.7],
#        [ 13.2],
#        [ 18.7],
#        [ 59.6],
#        [180.8],
#        [ 68.4],
#        [ 25. ],
#        [ 36.9],
#        [ 31.5],
#        [142.9],
#        [209.6],
#        [215.4],
#        [102.7],
#        [  8.6],
#        [ 16.9],
#        [125.7],
#        [104.6],
#        [109.8],
#        [229.5],
#        [253.8],
#        [184.9],
#        [ 44.7],
#        [ 62.3],
#        [292.9],
#        [172.5],
#        [202.5],
#        [  7.3]])

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = lr.predict(X_train)
print(y_pred_train)
# Out:
# [19.46077371 16.36372418 17.32124393 14.05926277 15.15880698 17.28459246
#  19.34623785 14.80145511 11.91057012 10.80644447 15.78188203 13.46367632
#  19.85019562 20.89018119 11.71814988 12.34122494 19.01179316 16.6615174
#  18.31083372 16.18504824 16.06593095 11.42035666  9.28082688  9.06091804
#   7.91097805 18.27418225  8.09881685 16.96389206  8.48365733 15.41994873
#  16.78979756 10.33913818 14.16921719 13.23918604 11.6265212  19.98763864
#  19.99680151  7.66816203 18.80562862 15.36039009  7.84683797 10.769793
#  16.46451573 17.8526903  12.23127051 17.65568863 14.79229224 13.31707042
#  16.78521613 15.41994873 17.24335955 10.37578966 17.71982871 16.16214107
#  11.77770853 11.23709929 17.77022448 13.7019109   9.52364289 17.3166625
#  16.26293263  7.55820761 18.22378647 17.22503381 17.49991986  8.57070458
#  14.251683   13.6881666  12.68025107 20.30375761  9.94513484 18.187135
#  17.09217222  8.1721198   7.49864897 14.84726945 11.6127769   8.62110035
#  17.94431898 17.14714943  8.1996084  20.14798884 20.62903943 13.55072357
#  10.47199978  9.34954839 13.78437671 15.94223223 20.76190103 13.62860795
#   7.69565064 15.02594539 20.20296605  9.28540831 17.38080257 15.67650905
#  14.17379862 17.40370975 11.69524271 18.7094185  10.89349172 12.85434557
#  12.4832494   8.13088689 10.98512041 18.69109276 11.76396422 17.41287261
#  20.33582764 18.45285818 10.54530272 13.50490923 10.76063013 12.62527386
#  10.75146726  9.05175517 14.95264244  8.53863454 12.8314384  19.35540072
#  18.0542734  18.29708942 20.41371203 17.49991986  9.12047668 17.75648018
#  16.9684735  10.67358288 11.35621658 16.43244569 12.38245784 19.53865809
#  18.187135   16.46451573 15.91932506 13.69274803  8.09881685 10.81102591
#  18.30167085  8.20877127]

# %%
plt.scatter(X_train, y_train, marker='x', c='r')
plt.plot(X_train, y_pred_train, c='b')
plt.xlabel('TV')
plt.ylabel('Price')
plt.title('TV vs Price')
plt.show()

# %%
r2_score(y_train, y_pred_train)
# Out:
# 0.5552336104251212

# %%
y_pred_test = lr.predict(X_test)
print(y_pred_test)
# Out:
# [10.48116264  9.60152727 11.4524267  20.58322509 15.1084112   9.8855762
#   7.70939494 18.31083372  8.40119151 16.36372418 19.28209777 11.3058208
#  14.48533615 15.91474363 10.81102591 12.81769409 19.47909945  7.3428802
#  10.73314153 17.08759078 20.48701497 13.73856237 15.33290148 13.34455903
#   9.76187747 12.95055569 14.89766523 16.70275031 17.57322281  8.46075015
#  10.41702256 16.42328282 20.17089601 18.38413667  7.91555948  8.16753836
#  10.04134496 15.59404323 10.44451117  8.45616872  9.00135939  8.75396194
#  13.85767966 16.91349628 17.17921947 12.01594311  7.70481351  8.08507255
#  13.06967298 12.10299036 12.34122494 17.82520169 18.93849021 15.78188203
#   9.35871126 10.16504368 20.72983099 15.21378419 16.58821446  7.64525486]

# %%
plt.scatter(X_test, y_test, marker='x', c='r')
plt.plot(X_test, y_pred_test, c='b')
plt.xlabel('TV')
plt.ylabel('Price')
plt.title('TV vs Price')
plt.show()

# %%
r2_score(y_test, y_pred_test)
# Out:
# 0.725606346597073
